# %%
import aylien_news_api
import urllib
import nltk
from aylien_news_api.rest import ApiException
from bs4 import BeautifulSoup
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
import os
java_path = "C:/Program Files/Java/jdk-10.0.1/bin/java.exe"
os.environ['JAVAHOME'] = java_path

# Only need to run this once
# nltk.download('punkt')


# Configure API key authorization: app_id
aylien_news_api.configuration.api_key['X-AYLIEN-NewsAPI-Application-ID'] = 'c45042a9'
# Configure API key authorization: app_key
aylien_news_api.configuration.api_key['X-AYLIEN-NewsAPI-Application-Key'] = 'a9270fe1446fc3fb7c8e8196ed52e626'

# create an instance of the API class
api_instance = aylien_news_api.DefaultApi()

url = "https://www.cnn.com/2018/04/24/politics/melania-trump-white-house/index.html"
html = urllib.request.urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
raw_text = soup.get_text()

# This needs to be changed to match your NER directory
st = StanfordNERTagger('C:/Users/Francis/Documents/Search and Data Mining/CPEG457/Aylien-api/NER/classifiers/english.all.3class.distsim.crf.ser.gz',
                         'C:/Users/Francis/Documents/Search and Data Mining/CPEG457/Aylien-api/NER/stanford-ner.jar',
                         encoding='utf-8')

tokenized_text = word_tokenize(raw_text)
classified_text = st.tag(tokenized_text)

print(classified_text)

def getStories(author_name):
    # Takes in authors name, sets it as an option for the api
    opts = {
      'author_name': author_name
    }

    try:
        # Creates an associative array of the stories
        api_response = api_instance.list_stories(**opts)
        return api_response
    except ApiException as e:
        print("Exception when calling DefaultApi->list_stories: %sn" % e)
        
        
author = "Kevin Liptak"
api_response = getStories(author)
for element in api_response.stories:
        print(element.title)
        print(element.links.permalink)
# Out:
# [('Melania', 'PERSON'), ('Trump', 'PERSON'), ('masters', 'O'), ('the', 'O'), ('moment', 'O'), ('-', 'O'), ('CNNPolitics', 'O'), ('{', 'O'), ('``', 'O'), ('@', 'O'), ('context', 'O'), ("''", 'O'), (':', 'O'), ('``', 'O'), ('http', 'O'), (':', 'O'), ('schema.org', 'O'), ("''", 'O'), (',', 'O'), ('``', 'O'), ('@', 'O'), ('type', 'O'), ("''", 'O'), (':', 'O'), ('``', 'O'), ('WebPage', 'O'), ("''", 'O'), (',', 'O'), ("''", 'O'), ('name', 'O'), ("''", 'O'), (':', 'O'), ('``', 'O'), ('Melania', 'PERSON'), ('Trump', 'PERSON'), ('masters', 'O'), ('the', 'O'), ('moment', 'O'), ("''", 'O'), (',', 'O'), ('``', 'O'), ('speakable', 'O'), ("''", 'O'), (':', 'O'), ('{', 'O'), ('``', 'O'), ('@', 'O'), ('type', 'O'), ("''", 'O'), (':', 'O'), ('``', 'O'), ('SpeakableSpecification', 'O'), ("''", 'O'), (',', 'O'), ("''", 'O'), ('cssSelector', 'O'), ("''", 'O'), (':', 'O'), ('[', 'O'), ('``', 'O'), ('.pg-headline', 'O'), ("''", 'O'), (',', 'O'), ('``', 'O'), ('.speakable', 'O'), ("''", 'O'), (']', 'O'), ('}', 'O'), (',', 'O'), ('``', 'O'), ('url', 'O'), ("''", 'O'), (':', 'O'), ('``', 'O'), ('https', 'O'), (':', 'O'), ('www.cnn.com20180424politicsmelania-trump-white-houseindex.html', 'O'), ("''", 'O'), ('}', 'O'), ('if', 'O'), ('(', 'O'), ('(', 'O'), ('typeof', 'O'), ('window.innerHeight', 'O'), ('===', 'O'), ("'number", 'O'), ("'", 'O'), ('&', 'O'), ('&', 'O'), ('window.innerHeight', 'O'), ('<', 'O'), ('0', 'O'), ('&', 'O'), ('&', 'O'), ('window.innerHeight', 'O'), ('>', 'O'), ('=', 'O'), ('0', 'O'), (')', 'O'), ('||false', 'O'), (')', 'O'), ('{', 'O'), ('if', 'O'), ('(', 'O'), ('typeof', 'O'), ('window.stop', 'O'), ('===', 'O'), ("'function", 'O'), ("'", 'O'), (')', 'O'), ('{', 'O'), ('window.stop', 'O'), ('(', 'O'), (')', 'O'), (';', 'O'), ('}', 'O'), ('else', 'O'), ('{', 'O'), ('document.execCommand', 'O'), ('(', 'O'), ("'Stop", 'O'), ("'", 'O'), (')', 'O'), (';', 'O'), ('}', 'O'), ('}', 'O'), ('var', 'O'), ('CNN', 'ORGANIZATION'), ('=', 'O'), ('CNN', 'O'), ('||', 'O'), ('{', 'O'), ('}', 'O'), (',', 'O'), ('CNNI', 'ORGANIZATION'), ('=', 'O'), ('CNNI', 'ORGANIZATION'), ('||', 'O'), ('{', 'O'), ('}', 'O'), (',', 'O'), ('FAVE', 'O'), ('=', 'O'), ('FAVE', 'O'), ('||', 'O'), ('{', 'O'), ('}', 'O'), (';', 'O'), ('window.document.domain', 'O'), ('=', 'O'), ("'cnn.com", 'O'), ("'", 'O'), (';', 'O'), ('if', 'O'), ('(', 'O'), ('typeof', 'O'), ('window.console', 'O'), ('===', 'O'), ("'undefined", 'O'), ("'", 'O'), (')', 'O'), ('{', 'O'), ('window.console', 'O'), ('=', 'O'), ('{', 'O'), ('debug', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('true', 'O'), (';', 'O'), ('}', 'O'), (',', 'O'), ('error', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('true', 'O'), (';', 'O'), ('}', 'O'), (',', 'O'), ('info', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('false', 'O'), (';', 'O'), ('}', 'O'), (',', 'O'), ('warn', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('false', 'O'), (';', 'O'), ('}', 'O'), (',', 'O'), ('log', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('false', 'O'), (';', 'O'), ('}', 'O'), (',', 'O'), ('timeStamp', 'O'), (':', 'O'), ('function', 'O'), ('(', 'O'), (')', 'O'), ('{', 'O'), ('return', 'O'), ('false', 'O'), (';', 'O'), ('}', 'O'), ('}', 'O'), ('}', 'O'), ('CNN.adTargets', 'O'), ('=', 'O'), ('{', 'O'), ('protocol', 'O'), (':', 'O'), ('``', 'O'), ('ssl', 'O'), ("''", 'O'), ('}', 'O'), (';', 'O'), ('CNN.AdsConfig', 'O'), ('=', 'O'), ('{', 'O'), ('adfuelServicesHost', 'O'), (':', 'O'), ("'adfuel.api.cnn.io", 'O'), ("'", 'O'), (',', 'O'), ('enableAdLock', 'O'), (':', 'O'), ('true', 'O'), (',', 'O'), ('enableGalleryAdRefresh', 'O'), (':', 'O'), ('true', 'O'), (',', 'O'), ('galleryAdClicks', 'O'), (':', 'O'), ('6', 'O'), (',', 'O'), ('amazon', 'O'), (':', 'O'), ('{', 'O'), ('``', 'O'), ('amznkey', 'O'), ("''", 'O'), (':', 'O') ...
# Trump walks back Giuliani: 'He'll get his facts straight'
# https://www.cnn.com/2018/05/04/politics/trump-giuliani-facts/index.html
# Trump on Giuliani: 'He'll get his facts straight'
# http://rss.cnn.com/~r/rss/cnn_latest/~3/uCrFNQi6NQU/index.html
# Trump silent on porn star payment storm at National Day of Prayer
# http://rss.cnn.com/~r/rss/cnn_latest/~3/uG1BvF4PDlc/index.html
# Will he or won't he? Trump's stance on Mueller testimony
# http://rss.cnn.com/~r/rss/cnn_latest/~3/BEfhxFZlyvI/index.html
# Trump rips Justice Department in stinging set of tweets
# https://www.cnn.com/2018/05/02/politics/donald-trump-justice-department/index.html
# Trump threatens to take on Justice Department's 'rigged system'
# http://rss.cnn.com/~r/rss/cnn_latest/~3/OvJ_3x15iGc/index.html
# White House claims 'clerical error' led to drastic change in Iran statement
# http://rss.cnn.com/~r/rss/cnn_latest/~3/QxjHUVIlGAg/index.html
# Trump welcomes first leader from sub-Saharan Africa
# http://rss.cnn.com/~r/rss/cnn_latest/~3/tWoU5UIX4U0/index.html
# Trump praises Jackson, says he was smeared
# http://www.wiscnews.com/video/featured/trump-praises-jackson-says-he-was-smeared/article_ebe694de-f941-595b-81be-9f318b9e57af.html
# Trump says two sites on table for Kim talks
# https://www.cnn.com/2018/04/27/politics/trump-north-korea/index.html
